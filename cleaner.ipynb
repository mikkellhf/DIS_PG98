# %%
import pandas as pd
import os


# # Read the CSV file
# df_health = pd.read_csv('gapminder.csv')

# # Remove commas from the Population column and convert it to integer
# df_health['Population'] = df_health['Population'].str.replace(',', '')

# # Remove double quotes from all columns
# df_health = df_health.replace('"', '')

# # Save the cleaned data to a new CSV file
# df_health.to_csv('health_cleaned.csv', index=False)
# os.chmod('health_cleaned.csv', 0o666)  # 0o666 means read and write permissions for everyone


# print("Data cleaned and saved to 'health_cleaned.csv'")
# df_money = pd.read_csv('gdpr.csv')
# # Make the gdp of the a million times smaller and convert it into a integer
# df_money['gdp'] = df_money['gdp'] / 1000000
# df_money['gdp'] = df_money['gdp'].astype(int)
# #Make the file into a csv file and make sure it is accassible to the user
# #ie give everyone permission to read and write
# df_money.to_csv('gdp_cleaned.csv', index=False)
# os.chmod('gdp_cleaned.csv', 0o666)  # 0o666 means read and write permissions for everyone

# print("Data cleaned and saved to 'gdp_cleaned.csv'")

# #Lets make sure that the columns country and continents are strings
# df_continents = pd.read_csv('Countries by continents.csv')
# df_continents['Country'] = df_continents['Country'].astype(str)
# df_continents['Continent'] = df_continents['Continent'].astype(str)
# df_continents.to_csv('Countries by continents.csv', index=False)
# os.chmod('Countries by continents.csv', 0o666)  # 0o666 means read and write permissions for everyone
# df_continents.to_csv('continents_cleaned.csv', index=False)

# import os

# # Set file permissions to read and write for everyone
# os.chmod('C:/Users/Mikke/OneDrive - University of Copenhagen/Datalogi/Semester 4/DIS/DIS_PG98/UIS_bank_v9/UIS_Prototype-master/bank/health_cleaned.csv', 0o666)
# os.chmod('C:/Users/Mikke/OneDrive - University of Copenhagen/Datalogi/Semester 4/DIS/DIS_PG98/UIS_bank_v9/UIS_Prototype-master/bank/gdp_cleaned.csv', 0o666)


# # We want to remove all but Country and Langauge from the data
# # The data set is world-data-2023.csv
# # We will save the new data set to world_data_cleaned.csv
df_world = pd.read_csv('language.csv')
df_world = df_world[['Country', 'Official language']]
df_world.to_csv('language_cleaned.csv', index=False)

# # We need to make sure the co-2 emissions are integers, so remove any "" or , and convert to int
# # Make sure if there are any that are not integers, replace with -1
# # It doesn't work. The data is not clean enough

# # Use regex to replace " and , in 'Co2-Emissions' column
# df_world['Co2-Emissions'] = df_world['Co2-Emissions'].replace({'"': '', ',': ''}, regex=True)

# # Convert 'Co2-Emissions' to numeric, invalid parsing will be set as NaN
# df_world['Co2-Emissions'] = pd.to_numeric(df_world['Co2-Emissions'], errors='coerce')

# # Replace NaN values with -1
# df_world['Co2-Emissions'].fillna(-1, inplace=True)

# df_world.to_csv('world.csv', index=False)
 
# print("Data cleaned and saved to 'world_data_cleaned.csv'")
